# %%
setwd("./")

#Load libraries
library('corrplot')
# Out:
# corrplot 0.84 loaded

# %%
# analysis of fixation + SUS survey data
userdata <- read.table("OSSStudy4.csv", header=T)
df <- scale(userdata)
#png("subject-clusters.png")
h <- heatmap(df[,2:20], scale="column")
#graphics.off()

# just the heatmap's dendogram
#png("var-cluster.png")
plot(hclust(dist(t(df[,2:20]))), xlab="Variables")
#graphics.off()
# Out:
# plot without title
# Plot with title “Cluster Dendrogram”

# %%
h$rowInd
# Out:
#  [1]  7  8  6  2 10  5  4  9  3  1

# %%
grp1 <- c(1,3,9,4,5)
grp2 <- c(10,2,6,8,7)
